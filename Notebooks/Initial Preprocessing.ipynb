# %%
import numpy as np
import pandas as pd
#from langdetect import detect

# %%
news = pd.read_csv("Datasets/UN_News.csv")
news.dropna(inplace=True)
news.drop_duplicates(inplace=True)
news = news[news['Category'].str.contains(pat = "https") == False]
news['Category'].values
news
# Out:
#                                                    Title  \
# 0      منظمة العمل الدولية: العاملون من المنزل بحاجة ...
# 1      الأمم المتحدة: منع حدوث المجاعة في اليمن أولوي...
# 2      كورونا: علماء يسعون لفهم تحور الفيروس ويحذرون ...
# 3      أزمة غذاء طاحنة وأطفال يضطرون إلى التسول بالشو...
# 4      مع دخول الجائحة عامها الثاني، اليونيسف تدعو إل...
# ...                                                  ...
# 7140   الرئيسة التشيلية ميشيل باشيليت تدعو إلى التعدد...
# 8275   إثيوبيا / جنوب السودان: خبيرتان أمميتان تطالبا...
# 9313   لاجئ زاده الموسيقى: رحلة أيهم أحمد من اليرموك ...
# 10535  اليونيسف: أطفال اليمن على حافة الهاوية في ظل م...
# 11207       اليمن: قطاعا الصحة والتعليم على وشك الانهيار
#
#                                                  Content  \
# 0      جاء ذلك في تقرير جديد لمنظمة العمل الدولية أوض...
# 1      وقال ستيفان دوجاريك في المؤتمر الصحفي اليومي، ...
# 2      وقد اجتمع الخبراء في منتدى افتراضي استضافته من...
# ...

# %%
news['Category'].value_counts()
# Out:
# السلم والأمن               1897
# حقوق الإنسان                796
# الصحة                       615
# المساعدات الإنسانية         510
# المهاجرون واللاجئون         401
# شؤون الأمم المتحدة          318
# أهداف التنمية المستدامة     236
# تغير المناخ                 233
# المرأة                      204
# الثقافة والتعليم            198
# التنمية الاقتصادية          184
# القانون ومنع الجريمة         90
# Name: Category, dtype: int64

# %%
news.to_csv("Datasets/UN_News_no_NA_Dups.csv", index=False)

# %%
uni_news = pd.read_csv("Datasets/University_News.csv")
uni_news.dropna(inplace=True)
uni_news.drop_duplicates(inplace=True)
uni_news
# Out:
#                                                   Title  \
# 0     صُنف ضمن أفضل 100 ألف باحث في العالم: د. عبد ا...
# 1     تبحث عن حلول تغذوية مبكرة وبسيطة لأمراض مزمنة ...
# 2     المركز الأول لفريق جامعة بيرزيت في هاكثون التع...
# 3     محاضرة الكترونية حول تاريخ الهجرة واللجوء في ب...
# 4     طلبة وأساتذة كلية العلوم في جامعة بيرزيت: انفت...
# ...                                                 ...
# 3126  دائرة الهندسة المعمارية تشارك في مهرجان (IFAS ...
# 3127  أستاذا الإعلام في بيرزيت قنيص وأبو الرب يختتما...
# 3128  مركز تطوير الإعلام يشارك بمؤتمر لليونسكو في رو...
# 3129   د. جوني استبان يشارك في ورشة  دولية في جامعة ...
# 3130  وضع حجر الأساس للحديقة التكنولوجية في حرم جامع...
#
#                                                 Content  \
# 0     \n\tأظهرت قاعدة بيانات تقييم الإنتاج العلمي لل...
# 1     \n\t"لدي الكثير لأقدمه للوطن بعد أن أنتهي من د...
# 2     \n\tحصل فريق دائرة الهندسة الكهربائية وهندسة ا...
# 3     \n\tاستضاف مساق مدخل إلى دراسات اللجوء والهجرة...
# ...

# %%
uni_news['Category'].value_counts()
# Out:
# شراكة مجنمعية      417
# مجتمع الجامعة      411
# الجامعة            383
# طلاب               360
# دولى               238
# فعاليات            177
# ابحاث ومشاريع      149
# قصص مميزة          136
# ثقافة وفنون        119
# علوم وتكنولوجيا     72
# جوائز ومنح          66
# زيارات              66
# مؤتمرات             65
# خريجون              46
# رياضة               20
# Name: Category, dtype: int64

# %%
uni_news.to_csv("Datasets/University_News_no_NA_Dups.csv", index=False)

# %%
arabic_new = pd.read_csv("Datasets/Arabic_News_AL-Mashareq.csv")
arabic_new.drop_duplicates(inplace=True)
arabic_new.dropna(inplace=True)
arabic_new
# Out:
#                                                   Title  \
# 0     \n          المقاتلون السريان يثبتون جدارتهم ف...
# 1         \n          اليمن ينظم أموال الزكاة\n
# 2     \n          لبنان يجدد المعركة ضد الإرهاب بعد ...
# 3     \n          اليمن يطبق خطة أمنية مشتركة في حضر...
# 4     \n          صنعاء تشدد التدابير الأمنية خلال ر...
# ...                                                 ...
# 3174  \n          مصرف لبنان يشدد القواعد على التحوي...
# 3175  \n          برنامج الغذاء العالمي يندد بسوء اس...
# 3176  \n          مصر تحكم على 8 عناصر من داعش بالإع...
# 3177  \n          الحوثيون المدعومون من إيران يحرقون...
# 3178  \n          سعد الحريري يطالب بـ ’العدالة‘مع ا...
#
#                                                 Content  \
# 0     \nيروي القياديان العسكريان من الطائفة السرياني...
# 1     \nأكد مسؤولون في وزارة الادارة المحلية اليمنية...
# 2     \nتعهدت السلطات اللبنانية بمواصلة الحرب ضد الإ...
# 3     \nتنفذ قوات الأمن اليمنية المشتركة خطة موحدة ل...
# ...

# %%
arabic_new.to_csv("Datasets/Arabic_News_AL-Mashareq_no_Na_Dups.csv", index=False)

# %%
print(arabic_new['Category'].value_counts())
# Out:
# أمن             580
# إرهاب           375
# سياسة           256
# حقوق الإنسان    129
# صحة             100
# مجتمع            64
# عدالة            59
# إعلام            37
# تحليل            33
# Name: Category, dtype: int64
